# %% [markdown]
# ---
#
# ---
# # Manipulação de dataframe - TAREFA 2 - Parte III
# ---
#
# ---

# %% [markdown]
# ##1-) Leitura dos dados
#
# A base de dados [Churn_Modelling](https://github.com/malegopc/AM2PUCPOC/tree/main/Datasets/Churn) é utilizada para prever (classificar) quando um cliente irá parar de utilizar o serviço de um banco.
#
# Conjunto de dados (características):
#
# * Número de Instâncias: 10.000
#
# * Número de Atributos: 13 atributos (incluindo o target)
#
# * Informações dos Atributos:
#
#   1. RowNumber
#   2. CustomerId
#   3. Surname
#   4. CreditScore
#   5. Geography
#   6. Gender Age
#   7. Tenure
#   8. Balance
#   9. NumOfProducts
#   10. HasCrCard
#   11. IsActiveMember
#   12. EstimatedSalary
#   13. Exited (variável de destino - target)
#
# *Clone o repositório de dados da disciplina (https://github.com/malegopc/DSBD), faça a leitura do arquivo **Churn_Modelling.csv** disponível na pasta [Churn_Modelling](https://github.com/malegopc/AM2PUCPOC/tree/main/Datasets/Churn) e armazene-o numa variável do tipo dataframe. Basta utilizar a função [pd.read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) da biblioteca pandas.*

# %%
# !git clone "https://github.com/malegopc/DSBD"
# Out:
# Cloning into 'DSBD'...
# remote: Enumerating objects: 587, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 587 (delta 55), reused 71 (delta 28), pack-reused 457
# Receiving objects: 100% (587/587), 13.05 MiB | 24.66 MiB/s, done.
# Resolving deltas: 100% (263/263), done.

# %%
import pandas as pd

# lê arquivo de dados, atribue NaN para dados faltantes
bancodedados = pd.read_csv('DSBD/Datasets/Churn/Churn_Modelling.csv', na_values=['?'])
# imprime o tipo da variável "diabetes" como dataframe
print(type(bancodedados))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ##2-) Visualização do dataframe
#
# *Mostre as 5 primeiras e as 5 últimas linhas do dataframe.*

# %%
# imprime as 5 primeiras linhas dos dados montados
bancodedados.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
bancodedados.head(-5)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602     Hargrave          619    France  Female   42
# 1             2    15647311         Hill          608     Spain  Female   41
# 2             3    15619304         Onio          502    France  Female   42
# 3             4    15701354         Boni          699    France  Female   39
# 4             5    15737888     Mitchell          850     Spain  Female   43
# ...         ...         ...          ...          ...       ...     ...  ...
# 9990       9991    15798964   Nkemakonam          714   Germany    Male   33
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9993       9994    15569266       Rahman          644    France    Male   28
# 9994       9995    15719294         Wood          800    France  Female   29
#
# ...

# %% [markdown]
# ##3-) Eliminação manual de variáveis
#
# *Elimine as variáveis (colunas): 'RowNumber', 'CustomerId' e 'Surname'.*

# %%
del bancodedados["RowNumber"]
del bancodedados["CustomerId"]
del bancodedados["Surname"]

bancodedados.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# ##4-) Dados ausentes
#
# *Verifique se há dados ausentes no dataframe.*

# %%
# Mostra o número de dados non-null (não ausentes) e o tipo de cada atributo
print('Informações sobre os dados:\n')
bancodedados.info()
# Soma o número de dados null (ausentes)
print('\n\nSoma de dados null (vazios):\n')
bancodedados.isnull().sum()
# Out:
# Informações sobre os dados:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB
#
#
# Soma de dados null (vazios):
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# ...

# %% [markdown]
# ## 5-) Separa as variáveis
#
# *Utilizando a função **[iloc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html?highlight=iloc#pandas.DataFrame.iloc)**, copie para uma variável "X" os valores de todas as variáveis (colunas) do dataframe, exceto os valores da variável "Exited".*
#
# *E copie para uma variável "y" somente os valores da variável "Exited".*

# %%
x = bancodedados.iloc[0:, 0:10]
print(x)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
y = bancodedados.iloc[0:, 10]
print(y)

#print(bancodedados.Exited) #//comando para conferir.
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64
